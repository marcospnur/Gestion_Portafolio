# %%
import pandas as pd
import numpy as np
import yfinance as yf
from statsmodels.tsa.holtwinters import Holt
import datetime
import warnings
import requests # Import the requests library
from scipy.stats import percentileofscore, spearmanr
from tabulate import tabulate
#warnings.simplefilter(action='ignore', category=FutureWarning)


Activos_historicos=['NVDA', 'BBVA', 'WMT',"CAT", "MU", "SNDK", "WELL", "WDC", "GEV", "GOOGL", "LITE", "AMD", "DELL"]
ETFs_historicos=["QQQM", 'VDC', 'GLD']

# %%
### Filtro de Acciones

## Fijar rentabilidad de la banca
R_f=0.045

## Periodos a evaluar
periodos=[1,2,3,5,10]

## Activo a evaluar
activo_input = input("Activo a evaluar: ").upper()

#Datos a 10 años
hoy = datetime.date.today()
start_10y=hoy-datetime.timedelta(days=10*365)

data=yf.download(activo_input, start=start_10y, end=hoy, progress=False, auto_adjust=True)['Close']
print(data.sort_values(by="Date", ascending=False).head(6))
print(len(data))
# Out:
# Ticker             AMD
# Date
# 2026-09-09  521.099976
# 2026-09-08  505.739990
# 2026-09-04  477.570007
# 2026-09-03  456.160004
# 2026-09-02  457.059998
# 2026-09-01  459.609985
# 2512

# %%
### Filtro de Acciones

## Fijar rentabilidad de la banca
R_f=0.045

## Periodos a evaluar
periodos=[1,2,3,5,10]

## Activo a evaluar
activo_input = input("Activo a evaluar: ").upper()


## Descarga de datos historicos
Data=Activos_historicos+[activo_input]

# período de tiempo de 5 años
hoy = datetime.date.today()
start_10y=hoy-datetime.timedelta(days=5*365)

data=yf.download(Data, start=start_10y, end=hoy, progress=False, auto_adjust=True)['Close']

data.head()
# Out:
# 1 Failed download:
# ['']: ValueError('Empty ticker name')
# Ticker                 AMD      BBVA         CAT       DELL  GEV       GOOGL  \
# Date
# 2021-09-13 NaN  104.800003  4.824886  189.208267  45.531075  NaN  140.990875
# 2021-09-14 NaN  105.730003  4.802921  185.657196  44.863464  NaN  141.200851
# 2021-09-15 NaN  105.599998  4.861494  188.777054  46.244728  NaN  143.068085
# 2021-09-16 NaN  106.220001  4.956674  186.822556  46.686733  NaN  142.256332
# 2021-09-17 NaN  103.879997  4.868814  183.289795  46.286175  NaN  139.472824
#
# Ticker           LITE         MU       NVDA  SNDK        WDC       WELL  \
# Date
# 2021-09-13  87.570000  72.501450  22.079536   NaN  44.009571  78.262215
# 2021-09-14  85.910004  71.662827  22.169247   NaN  43.279961  77.658958
# 2021-09-15  86.500000  71.984634  22.267918   NaN  43.821514  77.073479
# 2021-09-16  86.470001  72.774483  22.169247   NaN  43.836567  77.898491
# 2021-09-17  85.379997  72.452682  21.828362   NaN  43.565784  76.141968
#
# Ticker            WMT
# Date
# 2021-09-13  45.421822
# 2021-09-14  45.183849
# 2021-09-15  45.262138
# 2021-09-16  45.412430
# 2021-09-17  45.318493
